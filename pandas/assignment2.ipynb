# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("mob.csv")

# %%
df=pd.DataFrame(data)
df
# Out:
#          Brand  Battery capacity (mAh)  Screen size (inches) Touchscreen  \
# 0      OnePlus                    4085                  6.67         Yes
# 1       Realme                    4000                  6.50         Yes
# 2        Apple                    3969                  6.50         Yes
# 3        Apple                    3110                  6.10         Yes
# 4           LG                    4000                  6.40         Yes
# ...        ...                     ...                   ...         ...
# 1354     Intex                    1500                  4.00         Yes
# 1355  Videocon                    2000                  5.00         Yes
# 1356     Intex                    1700                  4.50         Yes
# 1357     iBall                    1250                  4.00         Yes
# 1358     iBall                    2150                  5.00         Yes
#
#       Resolution x  Resolution y  Processor  RAM (MB)  Internal storage (GB)  \
# ...

# %%
df.head()
# Out:
#      Brand  Battery capacity (mAh)  Screen size (inches) Touchscreen  \
# 0  OnePlus                    4085                  6.67         Yes
# 1   Realme                    4000                  6.50         Yes
# 2    Apple                    3969                  6.50         Yes
# 3    Apple                    3110                  6.10         Yes
# 4       LG                    4000                  6.40         Yes
#
#    Resolution x  Resolution y  Processor  RAM (MB)  Internal storage (GB)  \
# 0          1440          3120          8     12000                  256.0
# 1          1080          2400          8      6000                   64.0
# 2          1242          2688          6      4000                   64.0
# 3           828          1792          6      4000                   64.0
# 4          1080          2340          8      6000                  128.0
#
#    Rear camera  Front camera Operating system Wi-Fi Bluetooth  GPS  \
# ...

# %%
df.groupby("Brand")['Screen size (inches)'].max()
# Out:
# Brand
# 10.or      6.18
# Acer       5.50
# Alcatel    6.20
# Apple      6.50
# Aqua       5.00
#            ...
# Zopo       5.50
# Zuk        5.50
# iBall      6.00
# iVoomi     5.86
# mPhone     5.50
# Name: Screen size (inches), Length: 76, dtype: float64

# %%
a=df.groupby("Brand")['Brand'].count()
print(a.head(20))
# Out:
# Brand
# 10.or           5
# Acer            2
# Alcatel        10
# Apple          17
# Aqua            1
# Asus           37
# Billion         1
# Black Shark     1
# BlackBerry     17
# Blu             2
# Cat             4
# Celkon          4
# Comio           8
# Coolpad        19
# Gionee         33
# Google         10
# HP              1
# HTC            35
# Homtom          3
# Honor          33
# Name: Brand, dtype: int64

# %%
b=df.groupby("Brand")["Processor"].max()
b
# Out:
# Brand
# 10.or       8
# Acer        8
# Alcatel     8
# Apple       6
# Aqua        4
#            ..
# Zopo       10
# Zuk         4
# iBall       8
# iVoomi      4
# mPhone      8
# Name: Processor, Length: 76, dtype: int64

# %%
c=df.groupby("Operating system")['Operating system'].count()
c
# Out:
# Operating system
# Android       1299
# BlackBerry      10
# Cyanogen        10
# Sailfish         1
# Tizen            3
# Windows         19
# iOS             17
# Name: Operating system, dtype: int64

# %%
df["Brand"].count()
# Out:
# 1359

# %%
d=df.agg({
    'RAM (MB)':["max", "min"],
    'Resolution x':["max", "min"],
    'Resolution y':["max", "min"]
})
d
# Out:
#      RAM (MB)  Resolution x  Resolution y
# max     12000          2160          3840
# min        64           240           320
