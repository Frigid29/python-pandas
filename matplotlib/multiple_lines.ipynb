# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
y=np.random.randint(1,99,5)
print(y)
# Out:
# [26 64 81 92 82]

# %%
x=np.random.randint(1,99,5)
print(x)
# Out:
# [56 14 77 34 72]

# %%
np.random.seed(11)

# %% [markdown]
# #multiple lines in the same graph

# %%
plt.plot(x, color='g')
plt.plot(y, color='hotpink')
plt.show()
