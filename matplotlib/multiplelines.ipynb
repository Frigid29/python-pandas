# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x=np.array([1,9,3,7,4,6])

# %%
y=np.array([9,1,7,3,6,4])

# %%
plt.plot(x)
plt.plot(y)
plt.show()

# %%
plt.plot(x)
plt.xlabel("itthe x ka raj hai")
plt.ylabel("kuch toh hai")
# Out:
# Text(0, 0.5, 'kuch toh hai')

# %%
plt.plot(y)
plt.title("demo graph", loc='left')
# Out:
# Text(0.0, 1.0, 'demo graph')

# %%
plt.plot(y)
plt.title("demo graph", loc='right')
# Out:
# Text(1.0, 1.0, 'demo graph')

# %%
plt.plot(y)
plt.title("demo graph")
# Out:
# Text(0.5, 1.0, 'demo graph')

# %%
plt.plot(x,y)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %%
plt.plot(x,y)
plt.xlabel("x axis", loc="right")
plt.ylabel("y axis", loc= "bottom")
plt.show()
